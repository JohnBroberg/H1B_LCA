# %% [markdown]
# # H1B Labor Condition Applications (Form ETA-9035)

# %%
# H1B Labor Condition Applications (Form ETA-9035)

# http://econdataus.com/h1bdata.htm

#source: US Department of Labor
#https://www.dol.gov/agencies/eta/foreign-labor/performance

#source: US Bureau of Labor Statistics 
#https://www.bls.gov/oes/tables.htm

# metadata: lca_cols
# https://www.dol.gov/sites/dolgov/files/ETA/oflc/pdfs/LCA_Record_Layout_FY2022_Q3.pdf

# DOL Guidance on Determining OES Wage Levels
# https://www.aila.org/infonet/dol-guidance-on-determining-oes-wage-levels

# 
# https://www.dol.gov/sites/doPrevailing Wage Determination Policy Guidancelgov/files/ETA/oflc/pdfs/Policy_Nonag_Progs.pdf

# git pull https://github.com/JohnBroberg/H1B_LCA.git

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## global variables

# %%
#columns to be read from LCA Excel file
lca_cols = ['CASE_NUMBER','CASE_STATUS', 'RECEIVED_DATE', 'DECISION_DATE', 'ORIGINAL_CERT_DATE'
           , 'VISA_CLASS', 'SOC_CODE', 'SOC_TITLE', 'FULL_TIME_POSITION'
           , 'TOTAL_WORKER_POSITIONS', 'EMPLOYER_NAME', 'NAICS_CODE', 'WORKSITE_WORKERS'
           , 'SECONDARY_ENTITY', 'SECONDARY_ENTITY_BUSINESS_NAME', 'WORKSITE_STATE'
           , 'WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_TO', 'WAGE_UNIT_OF_PAY'
           , 'PREVAILING_WAGE', 'PW_UNIT_OF_PAY', 'PW_WAGE_LEVEL']
#           , 'PW_OES_YEAR', 'PW_OTHER_SOURCE', 'PW_OTHER_YEAR', 'PW_SURVEY_PUBLISHER', 'PW_SURVEY_NAME']

# %% [markdown]
# # Fiscal Year 2021

# %%
# Download LCA_Disclosure_Data_FY2021_Q4.xlsx

df21q4 = pd.read_excel("https://www.dol.gov/sites/dolgov/files/ETA/oflc/pdfs/LCA_Disclosure_Data_FY2021_Q4.xlsx"
                      , usecols = lca_cols)

df21q4 = df21q4[(df21q4['VISA_CLASS']=='H-1B') & \
        (df21q4['FULL_TIME_POSITION']=='Y')]

df21q4
# Out:
#                CASE_NUMBER CASE_STATUS RECEIVED_DATE DECISION_DATE  \
# 0       I-200-21175-424928   Certified    2021-06-24    2021-07-01
# 1       I-200-21175-424959   Certified    2021-06-24    2021-07-01
# 2       I-200-21175-425244   Certified    2021-06-24    2021-07-01
# 3       I-200-21175-423449   Certified    2021-06-24    2021-07-01
# 4       I-200-21175-425533   Certified    2021-06-24    2021-07-01
# ...                    ...         ...           ...           ...
# 126571  I-200-21273-615946   Withdrawn    2021-09-30    2021-09-30
# 126572  I-200-21273-617427   Withdrawn    2021-09-30    2021-09-30
# 126573  I-200-21273-617937   Withdrawn    2021-09-30    2021-09-30
# 126574  I-200-21273-617987   Withdrawn    2021-09-30    2021-09-30
# 126575  I-200-21273-616173   Withdrawn    2021-09-30    2021-09-30
#
#        ORIGINAL_CERT_DATE VISA_CLASS    SOC_CODE  \
# 0                     NaT       H-1B  15-1132.00
# 1                     NaT       H-1B  17-2011.00
# 2                     NaT       H-1B  15-1121.00
# 3                     NaT       H-1B  13-2051.00
# 4                     NaT       H-1B  15-1133.00
# ...                   ...        ...         ...
# 126571                NaT       H-1B  15-1133.00
# 126572                NaT       H-1B  25-1011.00
# 126573                NaT       H-1B  15-1132.00
# 126574                NaT       H-1B  15-1132.00
# 126575                NaT       H-1B  11-3021.00
#
#                                         SOC_TITLE FULL_TIME_POSITION  \
# 0               Software Developers, Applications                  Y
# 1                             Aerospace Engineers                  Y
# 2                       Computer Systems Analysts                  Y
# 3                              Financial Analysts                  Y
# 4           Software Developers, Systems Software                  Y
# ...                                           ...                ...
# 126571      Software Developers, Systems Software                  Y
# 126572           Business Teachers, Postsecondary                  Y
# 126573          Software Developers, Applications                  Y
# 126574          Software Developers, Applications                  Y
# 126575  Computer and Information Systems Managers                  Y
#
#         TOTAL_WORKER_POSITIONS  ... WORKSITE_WORKERS  SECONDARY_ENTITY  \
# 0                            1  ...                1                No
# 1                            1  ...                1                No
# 2                            1  ...                1                No
# 3                            1  ...                1                No
# 4                            1  ...                1                No
# ...                        ...  ...              ...               ...
# 126571                       1  ...                1                No
# 126572                       1  ...                1                No
# 126573                       1  ...                1               Yes
# 126574                       1  ...                1               Yes
# 126575                       1  ...                1                No
#
#         SECONDARY_ENTITY_BUSINESS_NAME WORKSITE_STATE WAGE_RATE_OF_PAY_FROM  \
# 0                                  NaN             CA              145275.0
# 1                                  NaN             NC              150000.0
# 2                                  NaN             TX               97240.0
# 3                                  NaN             NY               90000.0
# 4                                  NaN             CA              140000.0
# ...                                ...            ...                   ...
# 126571                             NaN             TX               72384.0
# 126572                             NaN             TX               85000.0
# 126573            Ameriprise Financial             TN               80330.0
# 126574            Ameriprise Financial             TN               80330.0
# 126575                             NaN             CA              136864.0
#
#        WAGE_RATE_OF_PAY_TO  WAGE_UNIT_OF_PAY  PREVAILING_WAGE PW_UNIT_OF_PAY  \
# 0                      NaN              Year         120578.0           Year
# 1                 170000.0              Year         103064.0           Year
# 2                      NaN              Year          97240.0           Year
# 3                      NaN              Year          72363.0           Year
# 4                 160000.0              Year         120578.0           Year
# ...                    ...               ...              ...            ...
# 126571             85000.0              Year          72384.0           Year
# 126572                 NaN              Year          18340.0           Year
# 126573             92300.0              Year          80330.0           Year
# 126574             80350.0              Year          80330.0           Year
# 126575            136865.0              Year         136864.0           Year
#
#         PW_WAGE_LEVEL
# 0                  II
# 1                  IV
# 2                 III
# 3                   I
# 4                  II
# ...               ...
# 126571              I
# 126572              I
# 126573             II
# 126574             II
# 126575              I
#
# [120897 rows x 22 columns]

# %%
# df21q4 is FY21 Q4

min(df21q4['DECISION_DATE'])
# Out:
# Timestamp('2021-07-01 00:00:00')

# %%
max(df21q4['DECISION_DATE'])
# Out:
# Timestamp('2021-09-30 00:00:00')

# %%
# Download LCA_Disclosure_Data_FY2021_Q3.xlsx

df21q3 = pd.read_excel("https://www.dol.gov/sites/dolgov/files/ETA/oflc/pdfs/LCA_Disclosure_Data_FY2021_Q3.xlsx"
                      , usecols = lca_cols)

df21q3 = df21q3[(df21q3['VISA_CLASS']=='H-1B') & \
        (df21q3['FULL_TIME_POSITION']=='Y')]

df21q3
# Out:
#                CASE_NUMBER CASE_STATUS RECEIVED_DATE DECISION_DATE  \
# 0       I-200-20268-844482   Certified    2020-09-24    2020-10-01
# 2       I-200-20268-844555   Certified    2020-09-24    2020-10-01
# 3       I-200-20274-851229   Withdrawn    2020-09-30    2020-10-01
# 6       I-200-20268-843525   Certified    2020-09-24    2020-10-01
# 8       I-200-20268-844862   Certified    2020-09-24    2020-10-01
# ...                    ...         ...           ...           ...
# 405618  I-200-21174-422728   Certified    2021-06-23    2021-06-30
# 405619  I-200-21174-421215   Certified    2021-06-23    2021-06-30
# 405620  I-200-21174-421823   Certified    2021-06-23    2021-06-30
# 405623  I-200-21176-425669      Denied    2021-06-24    2021-06-30
# 405625  I-200-21174-421509   Certified    2021-06-23    2021-06-30
#
#        ORIGINAL_CERT_DATE VISA_CLASS    SOC_CODE  \
# 0                     NaT       H-1B  11-1011.00
# 2                     NaT       H-1B  11-1021.00
# 3                     NaT       H-1B  11-1021.00
# 6                     NaT       H-1B  11-2021.00
# 8                     NaT       H-1B  11-2021.00
# ...                   ...        ...         ...
# 405618                NaT       H-1B  41-9031.00
# 405619                NaT       H-1B  41-9031.00
# 405620                NaT       H-1B  41-9031.00
# 405623                NaT       H-1B  51-9012.00
# 405625                NaT       H-1B  53-6051.00
#
#                                                 SOC_TITLE FULL_TIME_POSITION  \
# 0                                        Chief Executives                  Y
# 2                         General and Operations Managers                  Y
# 3                         General and Operations Managers                  Y
# 6                                      Marketing Managers                  Y
# 8                                      Marketing Managers                  Y
# ...                                                   ...                ...
# 405618                                    Sales Engineers                  Y
# 405619                                    Sales Engineers                  Y
# 405620                                    Sales Engineers                  Y
# 405623  Separating, Filtering, Clarifying, Precipitati...                  Y
# 405625                          Transportation Inspectors                  Y
#
#         TOTAL_WORKER_POSITIONS  ... WORKSITE_WORKERS  SECONDARY_ENTITY  \
# 0                            1  ...              1.0                No
# 2                            1  ...              1.0                No
# 3                            1  ...              1.0                No
# 6                            1  ...              1.0                No
# 8                            1  ...              1.0                No
# ...                        ...  ...              ...               ...
# 405618                       1  ...              1.0                No
# 405619                       1  ...              1.0                No
# 405620                       1  ...              1.0                No
# 405623                       1  ...              1.0                No
# 405625                       1  ...              1.0                No
#
#         SECONDARY_ENTITY_BUSINESS_NAME WORKSITE_STATE WAGE_RATE_OF_PAY_FROM  \
# 0                                  NaN             CA              225000.0
# 2                                  NaN             UT              140806.4
# 3                                  NaN             OH              205000.0
# 6                                  NaN             TN              210000.0
# 8                                  NaN             WA              150000.0
# ...                                ...            ...                   ...
# 405618                             NaN             CA              125736.0
# 405619                             NaN             CA              166140.0
# 405620                             NaN             CA              222200.0
# 405623                             NaN             AK               52000.0
# 405625                             NaN             LA               70000.0
#
#        WAGE_RATE_OF_PAY_TO  WAGE_UNIT_OF_PAY  PREVAILING_WAGE PW_UNIT_OF_PAY  \
# 0                      NaN              Year         208000.0           Year
# 2                      NaN              Year          99528.0           Year
# 3                      NaN              Year         155813.0           Year
# 6                      NaN              Year         129834.0           Year
# 8                      NaN              Year         133619.0           Year
# ...                    ...               ...              ...            ...
# 405618                 NaN              Year         125736.0           Year
# 405619                 NaN              Year         150654.0           Year
# 405620                 NaN              Year         136947.0           Year
# 405623             61000.0              Year          52000.0           Year
# 405625                 NaN              Year          55162.0           Year
#
#         PW_WAGE_LEVEL
# 0                 NaN
# 2                  IV
# 3                  IV
# 6                 III
# 8                  II
# ...               ...
# 405618            III
# 405619             IV
# 405620            III
# 405623            NaN
# 405625            III
#
# [389544 rows x 22 columns]

# %%
# df21q3 is FY21 Q1-Q3

min(df21q3['DECISION_DATE'])
# Out:
# Timestamp('2020-10-01 00:00:00')

# %%
max(df21q3['DECISION_DATE'])
# Out:
# Timestamp('2021-06-30 00:00:00')

# %%
# CONCAT df21q4 (Q4) and df21q3 (Q1-Q3) into df21 (full fiscal year)

df21 = pd.concat([df21q4, df21q3], ignore_index = True)
df21
# Out:
#                CASE_NUMBER CASE_STATUS RECEIVED_DATE DECISION_DATE  \
# 0       I-200-21175-424928   Certified    2021-06-24    2021-07-01
# 1       I-200-21175-424959   Certified    2021-06-24    2021-07-01
# 2       I-200-21175-425244   Certified    2021-06-24    2021-07-01
# 3       I-200-21175-423449   Certified    2021-06-24    2021-07-01
# 4       I-200-21175-425533   Certified    2021-06-24    2021-07-01
# ...                    ...         ...           ...           ...
# 510436  I-200-21174-422728   Certified    2021-06-23    2021-06-30
# 510437  I-200-21174-421215   Certified    2021-06-23    2021-06-30
# 510438  I-200-21174-421823   Certified    2021-06-23    2021-06-30
# 510439  I-200-21176-425669      Denied    2021-06-24    2021-06-30
# 510440  I-200-21174-421509   Certified    2021-06-23    2021-06-30
#
#        ORIGINAL_CERT_DATE VISA_CLASS    SOC_CODE  \
# 0                     NaT       H-1B  15-1132.00
# 1                     NaT       H-1B  17-2011.00
# 2                     NaT       H-1B  15-1121.00
# 3                     NaT       H-1B  13-2051.00
# 4                     NaT       H-1B  15-1133.00
# ...                   ...        ...         ...
# 510436                NaT       H-1B  41-9031.00
# 510437                NaT       H-1B  41-9031.00
# 510438                NaT       H-1B  41-9031.00
# 510439                NaT       H-1B  51-9012.00
# 510440                NaT       H-1B  53-6051.00
#
#                                                 SOC_TITLE FULL_TIME_POSITION  \
# 0                       Software Developers, Applications                  Y
# 1                                     Aerospace Engineers                  Y
# 2                               Computer Systems Analysts                  Y
# 3                                      Financial Analysts                  Y
# 4                   Software Developers, Systems Software                  Y
# ...                                                   ...                ...
# 510436                                    Sales Engineers                  Y
# 510437                                    Sales Engineers                  Y
# 510438                                    Sales Engineers                  Y
# 510439  Separating, Filtering, Clarifying, Precipitati...                  Y
# 510440                          Transportation Inspectors                  Y
#
#         TOTAL_WORKER_POSITIONS  ... WORKSITE_WORKERS  SECONDARY_ENTITY  \
# 0                            1  ...              1.0                No
# 1                            1  ...              1.0                No
# 2                            1  ...              1.0                No
# 3                            1  ...              1.0                No
# 4                            1  ...              1.0                No
# ...                        ...  ...              ...               ...
# 510436                       1  ...              1.0                No
# 510437                       1  ...              1.0                No
# 510438                       1  ...              1.0                No
# 510439                       1  ...              1.0                No
# 510440                       1  ...              1.0                No
#
#         SECONDARY_ENTITY_BUSINESS_NAME WORKSITE_STATE WAGE_RATE_OF_PAY_FROM  \
# 0                                  NaN             CA              145275.0
# 1                                  NaN             NC              150000.0
# 2                                  NaN             TX               97240.0
# 3                                  NaN             NY               90000.0
# 4                                  NaN             CA              140000.0
# ...                                ...            ...                   ...
# 510436                             NaN             CA              125736.0
# 510437                             NaN             CA              166140.0
# 510438                             NaN             CA              222200.0
# 510439                             NaN             AK               52000.0
# 510440                             NaN             LA               70000.0
#
#        WAGE_RATE_OF_PAY_TO  WAGE_UNIT_OF_PAY  PREVAILING_WAGE PW_UNIT_OF_PAY  \
# 0                      NaN              Year         120578.0           Year
# 1                 170000.0              Year         103064.0           Year
# 2                      NaN              Year          97240.0           Year
# 3                      NaN              Year          72363.0           Year
# 4                 160000.0              Year         120578.0           Year
# ...                    ...               ...              ...            ...
# 510436                 NaN              Year         125736.0           Year
# 510437                 NaN              Year         150654.0           Year
# 510438                 NaN              Year         136947.0           Year
# 510439             61000.0              Year          52000.0           Year
# 510440                 NaN              Year          55162.0           Year
#
#         PW_WAGE_LEVEL
# 0                  II
# 1                  IV
# 2                 III
# 3                   I
# 4                  II
# ...               ...
# 510436            III
# 510437             IV
# 510438            III
# 510439            NaN
# 510440            III
#
# [510441 rows x 22 columns]

# %%
# no duplicate rows
len(df21)-len(df21.drop_duplicates())
# Out:
# 0

# %%
# there are duplicate Case Numbers
len(df21['CASE_NUMBER'])-len(df21['CASE_NUMBER'].drop_duplicates())
# Out:
# 3192

# %%
# remove duplcate cases, keeping row with latest Decision Date

df21 = df21.sort_values(['CASE_NUMBER', 'DECISION_DATE'], ascending = False) \
    .drop_duplicates(subset = 'CASE_NUMBER', keep = 'first', ignore_index = True)

# %%
len(df21['CASE_NUMBER'])-len(df21['CASE_NUMBER'].drop_duplicates())
# Out:
# 0

# %%
dup = df21[df21.duplicated(['CASE_NUMBER'], keep = False)]\
    .sort_values(['CASE_NUMBER', 'DECISION_DATE'], ascending = False)

dup
# Out:
# Empty DataFrame
# Columns: [CASE_NUMBER, CASE_STATUS, RECEIVED_DATE, DECISION_DATE, ORIGINAL_CERT_DATE, VISA_CLASS, SOC_CODE, SOC_TITLE, FULL_TIME_POSITION, TOTAL_WORKER_POSITIONS, EMPLOYER_NAME, NAICS_CODE, WORKSITE_WORKERS, SECONDARY_ENTITY, SECONDARY_ENTITY_BUSINESS_NAME, WORKSITE_STATE, WAGE_RATE_OF_PAY_FROM, WAGE_RATE_OF_PAY_TO, WAGE_UNIT_OF_PAY, PREVAILING_WAGE, PW_UNIT_OF_PAY, PW_WAGE_LEVEL]
# Index: []
#
# [0 rows x 22 columns]

# %%
df21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507249 entries, 0 to 507248
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CASE_NUMBER                     507249 non-null  object
#  1   CASE_STATUS                     507249 non-null  object
#  2   RECEIVED_DATE                   507249 non-null  datetime64[ns]
#  3   DECISION_DATE                   507249 non-null  datetime64[ns]
#  4   ORIGINAL_CERT_DATE              21123 non-null   datetime64[ns]
#  5   VISA_CLASS                      507249 non-null  object
#  6   SOC_CODE                        507249 non-null  object
#  7   SOC_TITLE                       507249 non-null  object
#  8   FULL_TIME_POSITION              507249 non-null  object
#  9   TOTAL_WORKER_POSITIONS          507249 non-null  int64
#  10  EMPLOYER_NAME                   507248 non-null  object
#  11  NAICS_CODE                      507249 non-null  int64
#  12  WORKSITE_WORKERS                507248 non-null  float64
#  13  SECONDARY_ENTITY                507249 non-null  object
#  14  SECONDARY_ENTITY_BUSINESS_NAME  134170 non-null  object
#  15  WORKSITE_STATE                  507248 non-null  object
#  16  WAGE_RATE_OF_PAY_FROM           507248 non-null  float64
#  17  WAGE_RATE_OF_PAY_TO             170701 non-null  float64
#  18  WAGE_UNIT_OF_PAY                507248 non-null  object
#  19  PREVAILING_WAGE                 507248 non-null  float64
#  20  PW_UNIT_OF_PAY                  507248 non-null  object
#  21  PW_WAGE_LEVEL                   466090 non-null  object
# dtypes: datetime64[ns](3), float64(4), int64(2), object(13)
# memory usage: 85.1+ MB

# %%
# Add WORKSITE_EMPLOYER column

df21['WORKSITE_EMPLOYER'] = df21['EMPLOYER_NAME']
df21.loc[df21['SECONDARY_ENTITY'] == 'Yes', 'WORKSITE_EMPLOYER'] = df21['SECONDARY_ENTITY_BUSINESS_NAME']

df21[['EMPLOYER_NAME','SECONDARY_ENTITY_BUSINESS_NAME','WORKSITE_EMPLOYER']]
# Out:
#                                     EMPLOYER_NAME  \
# 0                                NIC INFO TEK INC
# 1                                NIC INFO TEK INC
# 2                            Data S Solutions LLC
# 3                                 NY SYSTEMS INC.
# 4               The University of Texas at Dallas
# ...                                           ...
# 507244                      Intone Networks, Inc.
# 507245  The Salk Institute for Biological Studies
# 507246                           SoundHound, Inc.
# 507247                                Kyyba, Inc.
# 507248                   Georgia State University
#
#        SECONDARY_ENTITY_BUSINESS_NAME  \
# 0                Ameriprise Financial
# 1                Ameriprise Financial
# 2                        Capital One
# 3                            BEST BUY
# 4                                 NaN
# ...                               ...
# 507244                 The Kroger Co.
# 507245                            NaN
# 507246                            NaN
# 507247                   Schlumberger
# 507248                            NaN
#
#                                 WORKSITE_EMPLOYER
# 0                            Ameriprise Financial
# 1                            Ameriprise Financial
# 2                                    Capital One
# 3                                        BEST BUY
# 4               The University of Texas at Dallas
# ...                                           ...
# 507244                             The Kroger Co.
# 507245  The Salk Institute for Biological Studies
# 507246                           SoundHound, Inc.
# 507247                               Schlumberger
# 507248                   Georgia State University
#
# [507249 rows x 3 columns]

# %%
#Export df to compressed .csv

compression_opts = dict(method='zip', archive_name='h1b_lca_fy21.csv')  

#df21.to_csv('h1b_lca_fy21_data.zip', index=False, compression=compression_opts)
